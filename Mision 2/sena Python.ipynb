# %%
complejo = 5+3j

complejo.real
# Out:
# 5.0

# %%
complejo.imag
# Out:
# 3.0

# %%
lista = [3,4.2,'sena',[8,9],5]
print (lista[0])
print (lista[1])
print (lista[2])
print (lista[3])
print (lista[4])
# Out:
# 3
# 4.2
# sena
# [8, 9]
# 5

# %%
tupla= (8,"b",4.91)
len(tupla)
# Out:
# 3

# %%
frutas= set(['mango', 'pera', 'manzana', 'limon'])
frutas
# Out:
# {'limon', 'mango', 'manzana', 'pera'}

# %%
frutas.remove('manzana')
frutas
# Out:
# {'limon', 'mango', 'pera'}

# %%
futbolista=dict()
futbolista = {
    13:"MINA",21:"MESSI",10:"CRISTIANO",
    17:"Rodriguez",
    9:"Falcao"
}
futbolista
# Out:
# {13: 'MINA', 21: 'MESSI', 10: 'CRISTIANO', 17: 'Rodriguez', 9: 'Falcao'}

# %%
type(5)
type(5.5)
type('hola?')
type(True)
isinstance(7.2, float)
# Out:
# True

# %%
a=2020
type(a)
# Out:
# int

# %%
aprendiz="Maria"
lenguaje="Python"
print(aprendiz,"aprende",lenguaje)
# Out:
# Maria aprende Python
