# %%
from sklearn.datasets import make_classification

# Generar un dataset sintético
X, y = make_classification(n_samples=100, n_features=5, random_state=42)

# Convertir a DataFrame
df = pd.DataFrame(X, columns=[f'Feature_{i}' for i in range(1, 6)])

# Generar la matriz de correlación
corr_matrix = df.corr()

# Visualizar la matriz de correlación
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# Mostrar la matriz de correlación en consola
print("Matriz de Correlación:")
print(corr_matrix)
# Out:
# Matriz de Correlación:
#            Feature_1  Feature_2  Feature_3  Feature_4  Feature_5
# Feature_1   1.000000  -0.309667   0.939231   0.018863   0.038405
# Feature_2  -0.309667   1.000000  -0.617260  -0.956517   0.011416
# Feature_3   0.939231  -0.617260   1.000000   0.360942   0.027656
# Feature_4   0.018863  -0.956517   0.360942   1.000000  -0.023785
# Feature_5   0.038405   0.011416   0.027656  -0.023785   1.000000
